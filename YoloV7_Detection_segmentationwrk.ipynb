# %% [markdown]
# <a href="https://colab.research.google.com/github/Ketheesram/Semantic-Instance-Segmentation-in-Dynamic-Environment/blob/main/YoloV7_Detection_segmentationwrk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/RizwanMunawar/yolov7-segmentation

# %%
# %cd /content/yolov7-segmentation

# %%
# !pip install -r requirements.txt

# %%
# !python3 segment/predict.py --weights /content/drive/MyDrive/EE405-UndergraduateProject/yolov7-seg.pt --source "kethees.mp4" --trk
# Out:
# segment/predict: weights=['/content/drive/MyDrive/EE405-UndergraduateProject/yolov7-seg.pt'], source=kethees.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, trk=True
# YOLOv5 🚀 yolov7-segmentation-35-g74dcdaa Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# yolov7-iseg summary: 325 layers, 38268602 parameters, 0 gradients, 143.2 GFLOPs
# video 1/1 (1/485) /content/yolov7-segmentation/kethees.mp4: 384x640 3 persons, 1 car, 1 motorcycle, 1 bus, 3 trucks, 3096.6ms
# video 1/1 (2/485) /content/yolov7-segmentation/kethees.mp4: 384x640 4 persons, 1 car, 2 motorcycles, 1 bus, 3 trucks, 3767.4ms
# ...
